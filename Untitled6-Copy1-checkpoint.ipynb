# %%
import pandas as pd
df = pd.read_csv("df.csv")
df.head()
# Out:
#    Unnamed: 0             Name  Rank     Sport  Height              Nation  \
# 0           0    Aaron Rodgers    55  Football     188       United States
# 1           1       Adam Scott    95      Golf     183           Australia
# 2           2  Adrian Gonzalez    60  Baseball     188       United States
# 3           3   Alex Rodriguez    48  Baseball     190       United States
# 4           4  Alfonso Soriano    93  Baseball     185  Dominican Republic
#
#         Pay    Salary  Endorsements
# 0  22000000  14500000       7500000
# 1  17700000   8700000       9000000
# 2  21500000  21100000        400000
# 3  22900000  22600000        300000
# 4  18050000  18000000         50000

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Salary'],df['Endorsements'])

# %%
df['Sport'].unique()
# Out:
# array(['Football', 'Golf', 'Baseball', 'Basketball', 'Boxing', 'Racing',
#        'Soccer', 'Tennis', 'Cricket', 'Track'], dtype=object)

# %%
df['Sport'].value_counts()
#How many rows in each category of the Sport column
# Out:
# Baseball      27
# Basketball    18
# Football      17
# Soccer        15
# Tennis         6
# Racing         6
# Golf           5
# Boxing         4
# Cricket        1
# Track          1
# Name: Sport, dtype: int64

# %%
Football=df[df['Sport'].str.contains("Football")]
Football
# Out:
#     Unnamed: 0              Name  Rank     Sport  Height         Nation  \
# 0            0     Aaron Rodgers    55  Football     188  United States
# 8            8    Branden Albert    91  Football     196  United States
# 9            9  Brandon Marshall    97  Football     193  United States
# 11          11     Carlos Dunlap    84  Football     198  United States
# 18          18    Darrelle Revis    40  Football     180  United States
# 25          25        Drew Brees    66  Football     183  United States
# 29          29       Eli Manning    66  Football     193  United States
# 37          37       Geno Atkins    53  Football     185  United States
# 40          40       Jairus Byrd    94  Football     178  United States
# 41          41      Jason Peters    70  Football     193  United States
# 47          47  Matthew Stafford    18  Football     188  United States
# 51          51         Joe Haden    62  Football     180  United States
# ...

# %%
Soccer=df[df['Sport'].str.contains("Soccer")]
Soccer
# Out:
#     Unnamed: 0                Name  Rank   Sport  Height       Nation  \
# 33          33     Fernando Torres    63  Soccer     186        Spain
# 35          35       Franck Ribéry    92  Soccer     170       France
# 36          36         Gareth Bale    14  Soccer     183        Wales
# 38          38          Yaya Touré    59  Soccer     191  Ivory Coast
# 60          60        Lionel Messi     4  Soccer     169    Argentina
# 61          61         Luis Suárez   100  Soccer     181      Uruguay
# 69          69          Mesut Özil    89  Soccer     181      Germany
# 70          70              Neymar    16  Soccer     175       Brazil
# 76          76      Radamel Falcao    15  Soccer     177     Colombia
# 79          79    Robin van Persie    81  Soccer     183  Netherlands
# 89          89       Sergio Agüero    44  Soccer     173    Argentina
# 90          90      Steven Gerrard    86  Soccer     183      England
# ...

# %%
Soccer.mean()
# Out:
# Unnamed: 0      6.853333e+01
# Rank            4.800000e+01
# Height          1.805333e+02
# Pay             3.150000e+07
# Salary          2.343333e+07
# Endorsements    8.066667e+06
# dtype: float64

# %%
Football.mean()
# Out:
# Unnamed: 0      3.847059e+01
# Rank            6.388235e+01
# Height          1.898235e+02
# Pay             2.269029e+07
# Salary          2.002353e+07
# Endorsements    2.666765e+06
# dtype: float64
